# %% [markdown]
# <a href="https://colab.research.google.com/github/hjiwoong/Python/blob/main/03_%EC%84%A0%ED%83%9D%EA%B5%AC%EC%A1%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 파이썬 기초: 03. 선택 구조

# %% [markdown]
# ## 1. 비교 연산자 (Comparison Operators)
# * **개념**: 두 값의 크기를 비교하여 참(`True`) 또는 거짓(`False`)을 결과로 반환하는 연산자입니다.
# * **주요 연산자**:
#     * `==` : 같다
#     * `!=` : 다르다
#     * `>` / `<` : 크다 / 작다
#     * `>=` / `<=` : 크거나 같다 / 작거나 같다

# %%
a, b, c = 10, 20, 30
print(f'{a}=={b}: {a==b}')
print(f'{a}!={b}: {a!=b}')
print(f'{a}>{b}: {a>b}')
print(f'{b}<{c}: {b<c}')
print(f'{a}>={b}: {a>=b}')
print(f'{b}<={c}: {b<=c}')
# Out:
# 10==20: False
# 10!=20: True
# 10>20: False
# 20<30: True
# 10>=20: False
# 20<=30: True

# %% [markdown]
# ### random 라이브러리
# *  import random
# *  random.함수 이름()
# *  randint(시작값, 끝값) : 정수 중 하나를 무작위로 반환

# %%
import random
a=random.randint(1,5)
answer = int(input('랜덤 수를 맞혀보세요(1~5): '))
print(f'결과는: {a==answer}, 랜덤 수는: {a}')
# Out:
# 랜덤 수를 맞혀보세요(1~5): 5
# 결과는: False, 랜덤 수는: 2

# %%
#무작위로 정수 두개(a, b)를 생성한 다음에 a나누기b의 몫과 나머지를 출력
import random
a=random.randint(10,50)
b=random.randint(2,9)
my_quotient=int(input(f'{a}나누기 {b}의 몫: '))
my_remainder=int(input(f'{a}나누기 {b}의 나머지: '))
print(f'{a}나누기{b}의 몫 결과: {a//b==my_quotient}, 실제값: {a//b}')
print(f'{a}나누기{b}의 나머지 결과: {a%b==my_remainder}, 실제값: {a%b}')
# Out:
# 19나누기 9의 몫: 1
# 19나누기 9의 나머지: 1
# 19나누기9의 몫 결과: False, 실제값: 2
# 19나누기9의 나머지 결과: True, 실제값: 1

# %% [markdown]
# ## 2. 선택 구조 (Selection Structure)
# * **개념**: 조건식의 결과에 따라 실행할 문장을 결정하는 구조입니다.
# * **if 문**: 조건이 참일 때만 실행할 문장을 작성합니다.
# * **if-else 문**: 조건이 참일 때와 거짓일 때 실행할 문장을 각각 나누어 작성합니다.
# * **if-elif-else 문**: 여러 개의 조건을 순차적으로 체크해야 할 때 사용합니다.
# * **주의 사항**:
#     * 조건문 끝에는 반드시 **콜론(:)**을 붙여야 합니다.
#     * 실행할 문장은 반드시 **들여쓰기(Indentation)**를 해야 합니다.

# %% [markdown]
# ### if문
# ```
# if 조건식:
#   실행문
# ```
# ### if ~ else문
# ```
# if 조건식:
#   실행문1
# else:
#   실행문2
# ```
# ### if ~ elif ~ else문
# ```
# if 조건식1:
#   실행문1
# elif 조건식2:
#   실행문2
# else:
#   실행문3
# ```

# %%
#if문
import random
a=random.randint(1,100)
b=random.randint(1,100)
print(a,b)
if a<b:
  a,b = b,a
print(a,b)
# Out:
# 31 9
# 31 9

# %%
#if~else문
height1=int(input('키: '))
height2=int(input('키: '))
if height1>height2:
  print(f'키차이:{height1-height2}')
else:
  print(f'키차이:{height2-height1}')
# Out:
# 키: 180
# 키: 160
# 키차이:20

# %%
#if~elif~else문
fee=5000
age=int(input('나이: '))
if age<8:
  print(f'입장료: {fee*0.7}원')
elif age<60:
  print(f'입장료: {fee}원')
else:
  print(f'입장료: {fee*0.8}원')
# Out:
# 나이: 24
# 입장료: 5000원

# %%
#문제: 가격 할인
#입력 받은 가격이 10,000원 이상일 때 판매가에서 5%할인, 그렇지 않으면 할인하지 않음
price=int(input('가격: '))
if price>=10000:
  price *= 0.95
print(f'결제 금액: {price}원')
# Out:
# 가격: 10000
# 결제 금액: 9500.0원

# %%
# 문제: 짝수와 홀수 판별하기
num=int(input('정수: '))
if num%2==0:
  print('짝수')
else:
  print('홀수')
# Out:
# 정수: 2
# 짝수

# %%
# 문제: 무작위 주사위 굴리기
import random
dice1=random.randint(1,6)
dice2=random.randint(1,6)
print(f'첫 번째 주사위: {dice1}, 두 번째 주사위: {dice2}')
if dice1>dice2:
  print('첫 번째 주사위 승')
elif dice1<dice2:
  print('두 번째 주사위 승')
else:
  print('무승부')
# Out:
# 첫 번째 주사위: 1, 두 번째 주사위: 4
# 두 번째 주사위 승

# %%
# 문제: 스포츠 스태킹 개인 기록 정하기
try1=int(input('첫 번째 기록: '))
try2=int(input('두 번째 기록: '))
try3=int(input('세 번째 기록:'))
if try1<try2:
  if try1<try3:
    print(f'최고 기록: {try1}')
  else:
    print(f'최고 기록: {try3}')
if try2<try1:
  if try2<try3:
    print(f'최고 기록: {try2}')
  else:
    print(f'최고 기록: {try3}')
# Out:
# 첫 번째 기록: 15
# 두 번째 기록: 12
# 세 번째 기록:10
# 최고 기록: 10

# %% [markdown]
# ## 3. 논리 연산자 (Logical Operators)
# * **개념**: 여러 개의 조건식을 조합하여 하나의 결과를 얻을 때 사용합니다.
# * **종류**:
#     * `and` : 두 조건이 모두 참일 때만 참
#     * `or` : 두 조건 중 하나만 참이어도 참
#     * `not` : 참을 거짓으로, 거짓을 참으로 반전

# %%
a=25
print(a>8 and a<60)

a=70
print(a<8 or a>=60)

a=20
print(not a==20)
# Out:
# True
# True
# False

# %%
# 문제: 쇼핑몰 회원별 결제 금액 계산하기
delivery_fee=2000
level=input('회원 등급(우수/일반): ')
price=int(input('구매 금액: '))
if level=='우수' or price>=20000:
  print(f'결제 금액: {price}원, 배송비 0원')
else:
  print(f'상품:{price} + 배송비:{delivery_fee} = 결제 금액: {price+delivery_fee}원')
# Out:
# 회원 등급(우수/일반): 우수
# 구매 금액: 200
# 결제 금액: 200원, 배송비 0원

# %%
# 문제: 정수 입력 받아서 3의 배수이고 5의 배수인지 출력
num=int(input('정수: '))
if num%3==0 and num%5==0:
  print('3과 5의 배수')
else:
  print('3과 5의 배수가 아님')
# Out:
# 정수: 15
# 3과 5의 배수

# %%
# 문제: 연도를 입력받아서 윤년인지 평년인지 판별
year=int(input('연도: '))
if year%400==0 or (year%4==0 and year%100!=0):
  print(f'{year}년은 윤년입니다')
else:
  print(f'{year}년은 평년입니다')
# Out:
# 연도: 2024
# 2024년은 윤년입니다

# %%
# 가위바위보 게임
import random
user=input('가위, 바위, 보: ')
com_rand=random.randint(1,3)
if com_rand==1:
  computer = '가위'
elif com_rand==2:
  computer = '바위'
else:
  computer = '보'
print(f'나: {user}, 컴퓨터: {computer}')
# 승부 겨루기
if user=='가위':
  if computer=='가위':
    print('무승부')
  elif computer=='바위':
    print('컴퓨터 승리')
  else:
    print('사용자 승리')
elif user=='바위':
  if computer=='가위':
    print('사용자 승리')
  elif computer=='바위':
    print('무승부')
  else:
    print('컴퓨터 승리')
elif user=='보':
  if computer=='가위':
    print('컴퓨터 승리')
  elif computer=='바위':
    print('사용자 승리')
  else:
    print('무승부')
else:
  print('컴퓨터 승리')
# #승부 간단
# if user==computer:
#   print('무승부')
# elif user=='가위' and computer=='보':
#   print('사용자 승')
# elif user=='바위' and computer=='가위':
#   print('사용자 승')
# elif user=='보' and computer=='바위':
#   print('사용자 승')
# else:
#   print('컴퓨터 승')
# Out:
# 가위, 바위, 보: 가위
# 나: 가위, 컴퓨터: 바위
# 컴퓨터 승리

# %% [markdown]
# ## 4. 함수 (Function)
# * **개념**: 특정 작업을 수행하는 명령어들의 묶음입니다.
# * **라이브러리 활용**: `import` 키워드를 사용하여 외부 도구(라이브러리)를 불러올 수 있습니다.
# * **랜덤 함수**: `random.randint(start, end)`는 지정한 범위 내의 정수 중 하나를 무작위로 반환합니다.

# %%
import random
def rand_add():
  a=random.randint(1,100)
  b=random.randint(1,100)
  answer=int(input(f'{a}+{b}= '))
  if answer==a+b:
    print('정답')
  else:
    print('오답')
rand_add()
rand_add()
# Out:
# 53+80= 1
# 오답
# 96+18= 1
# 오답

# %% [markdown]
# ### 함수 정의
# ```
# def 함수 이름(매개변수1, 매개변수2):
#   실행문
#   return 반환값
# ```
# ### 함수 호출
# ```
# 함수아름(인자값1, 인자값2)
# ```

# %%
def func():
  print('함수입니다')
print('함수 호출 전 입니다')
func()
print('함수 호출 후 입니다')
# Out:
# 함수 호출 전 입니다
# 함수입니다
# 함수 호출 후 입니다

# %%
def add(x,y):
  print(x+y)
a=int(input('정수: '))
b=int(input('정수: '))
add(a,b)
# Out:
# 정수: 1
# 정수: 1
# 2

# %%
import random
def bigsmall(x,y):
  if x>y:
    return x, y
  else:
    return y, x
a=random.randint(1,100)
b=random.randint(1,100)
print(f'a:{a}, b:{b}')
a,b=bigsmall(a,b)
print(a,b)
# Out:
# a:55, b:40
# 55 40

# %%
### 사칙 연산 함수
def add(x,y):
  return x+y
def sub(x,y):
  return x-y
def mul(x,y):
  return x*y
def div(x,y):
  return x/y

a=int(input('정수: '))
b=int(input('정수: '))
print(f'더하기: {a}+{b}={add(a,b)}')
print(f'빼기: {a}-{b}={sub(a,b)}')
print(f'곱하기: {a}*{b}={mul(a,b)}')
print(f'나누기: {a}/{b}={div(a,b)}')
# Out:
# 정수: 2
# 정수: 4
# 더하기: 2+4=6
# 빼기: 2-4=-2
# 곱하기: 2*4=8
# 나누기: 2/4=0.5

# %%
# div 함수에서 몫, 나머지 반환
def div(x,y):
  return x//y, x%y
a=int(input('정수: '))
b=int(input('정수: '))
quotient, remainder = div(a,b)
print(f'{a} 나누기 {b}의 몫: {quotient}, 나머지: {remainder}')
# Out:
# 정수: 1
# 정수: 4
# 1 나누기 4의 몫: 0, 나머지: 1

# %% [markdown]
# ## 5. [실습 예제]
#
# ### 🌡️ 온도 변환기 (온도 종류 통합형)
# 1. **입력**: 사용자로부터 온도 종류(섭씨 또는 화씨)와 온도 값을 입력받습니다.
# 2. **판단 및 계산**:
#     * `if kind == '섭씨':` 이면 화씨 공식(`temp * 1.8 + 32`)으로 계산합니다.
#     * `else:` 이면 화씨로 간주하고 섭씨 공식(`(temp - 32) / 1.8`)으로 계산합니다.
# 3. **출력**: 변환된 온도 결과를 화면에 표시합니다.

# %%
#섭씨C 온도를 화씨F 온도로 변환
celsius=int(input('섭씨 온도: '))
celsius*9/5+32
# Out:
# 섭씨 온도: 12
# 53.6

# %%
# 화씨F 온도를 섭씨C 온도로 변환
fahrenheit=int(input('화씨 온도: '))
(fahrenheit-32)*5/9
# Out:
# 화씨 온도: 25
# -3.888888888888889

# %%
#kind 변수에 화씨인지 섭씨인지 입력받고 temp 변수에 온도를 입력하고 섭씨면 화씨로 변환, 화씨면 섭씨로 변환
kind=input('온도 종류(섭씨/화씨): ')
temp=int(input(f'{kind} 온도: '))
if kind=='섭씨':
  print(f'화씨 온도: {temp*9/5+32}')
elif kind=='화씨':
  print(f'섭씨 온도: {(temp-32)*5/9}')
else:
  print('오류')
# Out:
# 온도 종류(섭씨/화씨): 섭씨
# 섭씨 온도: 12
# 화씨 온도: 53.6

# %% [markdown]
# ### 📐 두 도형의 넓이 비교하기
# 1. **계산**: 사각형(가로×세로)과 삼각형(밑변×높이/2)의 정보를 각각 입력받아 넓이를 구합니다.
# 2. **비교**:
#     * `if 넓이1 > 넓이2:` 첫 번째 도형이 더 넓다고 출력합니다.
#     * `elif 넓이1 < 넓이2:` 두 번째 도형이 더 넓다고 출력합니다.
#     * `else:` 두 도형의 넓이가 같다고 출력합니다.

# %%
# 사각형은 가로세로, 삼각형은 밑변높이, 원은 반지름 함수 3개
import math
def square():
  width=int(input('사각형의 가로: '))
  height=int(input('사각형의 세로: '))
  return width*height
def triangle():
  base=int(input('삼각형의 밑변: '))
  height=int(input('삼각형의 높이: '))
  return base*height/2
def circle():
  radius=int(input('반지름: '))
  return math.pi*radius*radius

shape_type1=input('도형의 종류(사각형, 삼각형, 원): ')
if shape_type1=='사각형':
  area1=square()
  print(f'{shape_type1}의 넓이: {area1}')
elif shape_type1=='삼각형':
  area1=triangle()
  print(f'{shape_type1}의 넓이: {area1}')
elif shape_type1=='원':
  area1=circle()
  print(f'{shape_type1}의 넓이: {area1}')
else:
  print('"사각형", "삼각형, "원" 중 입력')

shape_type2=input('도형의 종류(사각형, 삼각형, 원): ')
if shape_type2=='사각형':
  area2=square()
  print(f'{shape_type2}의 넓이: {area2}')
elif shape_type2=='삼각형':
  area2=triangle()
  print(f'{shape_type2}의 넓이: {area2}')
elif shape_type2=='원':
  area2=circle()
  print(f'{shape_type2}의 넓이: {area2}')
else:
  print('"사각형", "삼각형, "원" 중 입력')

if area1>area2:
  print(f'첫 번째 {shape_type1}이 {area1-area2}cm²만큼 더 넓습니다')
elif area1<area2:
  print(f'두 번째 {shape_type2}이 {area2-area1}cm²만큼 더 넓습니다')
else:
  print(f'두 도형의 넓이는 {area1}cm²로 같습니다')
# Out:
# 도형의 종류(사각형, 삼각형, 원): 원
# 반지름: 5
# 원의 넓이: 78.53981633974483
# 도형의 종류(사각형, 삼각형, 원): 사각형
# 사각형의 가로: 20
# 사각형의 세로: 30
# 사각형의 넓이: 600
# 두 번째 사각형이 521.4601836602552cm²만큼 더 넓습니다
