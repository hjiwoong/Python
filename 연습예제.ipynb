# %% [markdown]
# <a href="https://colab.research.google.com/github/hjiwoong/Python/blob/main/%EC%97%B0%EC%8A%B5%EC%98%88%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1-1 각 변수의 선언에서 변수 선언 가능 여부
# 1.  name = "variable' (=에러)
# 2.  number = 41 (=정상 작동)
# 3.  int = 3 (=정상 작동)
# 4.  "name" = "variable" (=에러)
# 5. is_book = true (=에러)
# 6.  for = "repeat" (=에러)
# 7. data_type = ["", 1, 2] (=정상 작동)
# 8. 4things = [3.141, 2.718, 41, 1729] (=에러)
# <hr>
#
# ### 1-2 코드에서 각 문자열 변수의 대입 값 예측
# string = "ABCDE"
# 1. str1 = string[1]
#     * str1: B
# 2. str2 = string[-1]
#     * str2: E
# 3. str3 = string[1:3]
#     * str3: BC
# 4. str4 = string[:3]
#     * str4: ABC
# 5. str5 = string[-2:]
#     * str5: DE
# 6. str6 = string[1:-2]
#     * str6: BC
# <hr>
#
# ### 1-3 각 리스트 변수의 대입 값 예측
# nums = [1, 20, 300, 4000]
# 1. n1 = nums[1]
#     * n1: 20
# 2. n2 = nums[-1]
#     * n2: 4000
# 3. n3 = nums[1:3]
#     * n3: [20, 300]
# 4. n4 = nums[:3]
#     * n4: [1, 20, 300]
# 5. n5 = nums[-2:]
#     * n5: [300, 4000]
# 6. n6 = nums[1:2]
#     * n6: [20]
# <hr>
#
# ### 1-4 각 문자열 변수의 대입 값을 예측
# string = "ABCDE"

# %% [markdown]
# ### 5-1 코드 출력 결과 예측
# 1. print(5>4) : True
# 2. print(5>6) : False
# 3. print(3==3.0) : True
# 4. print("3"==3) : False
# 5. print("py" in "python") : True
# 6. print("PY" in "python") : False
# 7. print(3 in [1, 2, 3]) : True
# 8. print(3 < 4 and 4 < 7) : True
# 9. print(3 in [1, 2, 3] or 4 in [1, 2, 3]) : True
# 10. print(4 in [1, 2, 3] or 5 in [1, 2, 3]) : False
#  <hr>
#
#  ### 5-2 코드 실행 순서 나열
#  ```
#  1. a) n = 3
#     b) if n < 5:
#     c)   n = 5
#     d) print("n = {}".format(n))
#
#       a > b > c > d
# ```
# ```
# 2. a) n = 7
#    b) if n < 5:
#    c)   n=50
#    d) print("n={}".format(n))
#
#       a > b > d
# ```
# ```
# 3. a) n=8
#    b) if n < 5:
#    c)   print("small")
#    d) else:
#    e)   print("big")
#
#       a > b > d > e
# ```
# ```
# 4. a) n=2
#    b) if n<5:
#    c)   print("small")
#    d) else:
#    e)   print("big")
#
#       a > b > c
# ```

# %% [markdown]
# ### 6-1 코드에서 print가 실행되는 횟수
# ```
# 1. for i in [1,20,300]:
#      print(i)
#  =3회
# ```
# ```
# 2. for i in["apple", "banna"]:
#      print(i)
#  =2회
# ```
# ```
# 3. for i in range(3):
#      print(i)
#  =3회
# ```
# ```
# 4. for i in range(2,5):
#      print(i)
#  =3회
# ```
# ```
# 5. for i in range(2,2):
#      print(i)
#  =0회
# ```
# ```
# 6. for i in [1,20,300]:
#      print(i*2)
#  =3회
# ```
# ```
# 7. for i in range(3):
#      print("o"*i)
#  =3회
# ```
# ```
# 8. for i in range(4):
#      print(3)
#  =4회
# ```
# <hr>
#
# ### 6-2 코드 출력 결과 예측
# ```
# 1. arr = []
#    for i in range(5):
#      arr = arr + [i * 2]
#   print(arr)
#  =[0,2,4,6,8]
# ```
# ```
# 2. arr=[]
#    for i in range(5):
#      arr=arr+[str(i)]
#   print(arr)
#  =['0','1','2','3','4']
# ```
# ```
# 3. arr=[]
#    for i in range(5):
#      arr=arr+[i*str(i)]
#    print(arr)
#  =['','1','22','333','4444']
# ```
# ```
# 4. arr=[]
#    for i in range(5):
#      if i < 2:
#        arr=arr+[i]
#    print(arr)
#  =[0,1]
# ```
# ```
# 5. arr=[]
#    for i in range(5):
#      if i % 2 == 0:
#        arr=arr+[i]
#    print(arr)
#  =[0,2,4]
# ```
# <hr>
#
# ### 6-3 코드 출력 결과 예측

# %% [markdown]
# ### 3-1 내장함수

# %%
a=input()
print(a*2)
# Out:
# 3
# 33

# %%
a=input()
b=input()
print(a+b)
# Out:
# 3
# 4
# 34

# %%
a=int(input())
print(a*2)
# Out:
# 3
# 6

# %%
#숫자로 출력
a=input()
b=input()
c=int(a) + int(b)
print(c)
# Out:
# -5
# 4
# -1

# %%
#숫자로 출력
a=int(input())
b=int(input())
c=a+b
print(c)
# Out:
# 10
# 5
# 15

# %%
#문자로 출력
a=input()
b=input()
c=int(a+b)
print(c)
# Out:
# 10
# 5
# 105
